# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
name = 'meta_x'

# %%
hist_ss = pd.read_csv(os.path.join('metrics', f'{name}_hist.csv'),
                      index_col=0,
                      squeeze=True)
metrics_df = pd.read_csv(os.path.join('metrics', f'{name}_metrics.csv'))
example_df = pd.read_csv(os.path.join('metrics', f'{name}_examples.csv'))

# %%
plt.figure(figsize=(20, 5))
hist_ss.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
plt.xticks(np.around(np.arange(min(metrics_df['k']), max(metrics_df['k']) + 0.02, 0.02), 2))
metrics_df.set_index('k')['mean'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
plt.figure(figsize=(20, 5))
metrics_df.set_index('k')['std'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
bins = pd.qcut(example_df['purchases_30d__count'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                    y     uplift
# w   purchases_30d__count
# 0.0 (0.999, 2.0]          202.829050   0.116124
#     (2.0, 3.0]            256.898960 -12.273905
#     (3.0, 4.0]            257.694675 -18.783492
#     (4.0, 10.0]           258.426936 -22.783002
# 1.0 (0.999, 2.0]          206.625274   0.237076
#     (2.0, 3.0]            244.126343 -11.840601
#     (3.0, 4.0]            237.370450 -18.872732
#     (4.0, 10.0]           237.842184 -21.906673

# %%
bins = pd.qcut(example_df['purchases_sum_30d__sum'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                             y     uplift
# w   purchases_sum_30d__sum
# 0.0 (85.02799999999999, 1027.773]  113.381924   5.186990
#     (1027.773, 1486.169]           142.074634   2.557894
#     (1486.169, 1908.069]           172.041740  -1.532377
#     (1908.069, 2328.167]           193.264216  -5.820639
#     (2328.167, 2760.356]           213.981228  -6.012277
#     (2760.356, 3244.932]           229.691224  -9.191136
#     (3244.932, 3843.417]           255.955372  -7.987666
#     (3843.417, 4613.921]           294.961684 -11.188383
#     (4613.921, 5664.935]           327.691156 -18.434898
#     (5664.935, 10710.174]          300.287233  -9.107988
# 1.0 (85.02799999999999, 1027.773]  117.004555   5.290530
#     (1027.773, 1486.169]           144.466157   2.860827
#     (1486.169, 1908.069]           171.611987  -1.481165
#     (1908.069, 2328.167]           191.135324  -6.110949
#     (2328.167, 2760.356]           210.865792  -5.460002
#     (2760.356, 3244.932]           226.932555  -8.812023
#     (3244.932, 3843.417]           246.437779  -7.938049
#     (3843.417, 4613.921]           283.993177 -10.805685
#     (4613.921, 5664.935]           315.891878 -18.648502
#     (5664.935, 10710.174]          294.078754  -8.372356
