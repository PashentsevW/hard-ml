# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
name = 'test'

# %%
hist_ss = pd.read_csv(os.path.join('metrics', f'{name}_hist.csv'),
                      index_col=0,
                      squeeze=True)
metrics_df = pd.read_csv(os.path.join('metrics', f'{name}_metrics.csv'))
example_df = pd.read_csv(os.path.join('metrics', f'{name}_examples.csv'))

# %%
plt.figure(figsize=(20, 5))
hist_ss.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
plt.xticks(np.around(np.arange(min(metrics_df['k']), max(metrics_df['k']) + 0.02, 0.02), 2))
metrics_df.set_index('k')['mean'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
plt.figure(figsize=(20, 5))
metrics_df.set_index('k')['std'].plot.line()
# Out:
# <AxesSubplot:xlabel='k'>

# %%
bins = pd.qcut(example_df['purchases_30d__count'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                    y     uplift
# w   purchases_30d__count
# 0.0 (0.999, 2.0]          202.829050   0.180463
#     (2.0, 3.0]            256.898960 -11.369109
#     (3.0, 4.0]            257.694675 -16.858106
#     (4.0, 10.0]           258.426936 -17.768870
# 1.0 (0.999, 2.0]          206.625274   0.230618
#     (2.0, 3.0]            244.126343 -11.279176
#     (3.0, 4.0]            237.370450 -16.837477
#     (4.0, 10.0]           237.842184 -17.655165

# %%
bins = pd.qcut(example_df['purchases_sum_30d__sum'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                             y     uplift
# w   purchases_sum_30d__sum
# 0.0 (85.02799999999999, 1027.773]  113.381924   5.997687
#     (1027.773, 1486.169]           142.074634   2.705001
#     (1486.169, 1908.069]           172.041740  -0.967660
#     (1908.069, 2328.167]           193.264216  -4.003043
#     (2328.167, 2760.356]           213.981228  -6.066564
#     (2760.356, 3244.932]           229.691224  -7.478143
#     (3244.932, 3843.417]           255.955372  -9.658259
#     (3843.417, 4613.921]           294.961684 -11.552769
#     (4613.921, 5664.935]           327.691156 -12.713803
#     (5664.935, 10710.174]          300.287233 -10.168032
# 1.0 (85.02799999999999, 1027.773]  117.004555   6.221516
#     (1027.773, 1486.169]           144.466157   2.743638
#     (1486.169, 1908.069]           171.611987  -0.893239
#     (1908.069, 2328.167]           191.135324  -4.105008
#     (2328.167, 2760.356]           210.865792  -5.980583
#     (2760.356, 3244.932]           226.932555  -7.652281
#     (3244.932, 3843.417]           246.437779  -9.657610
#     (3843.417, 4613.921]           283.993177 -11.520913
#     (4613.921, 5664.935]           315.891878 -12.625648
#     (5664.935, 10710.174]          294.078754  -9.723561
