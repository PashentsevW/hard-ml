# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
name = 'rf'

# %%
hist_ss = pd.read_csv(os.path.join('metrics', f'{name}_hist.csv'),
                      index_col=0,
                      squeeze=True)
metrics_df = pd.read_csv(os.path.join('metrics', f'{name}_metrics.csv'))
example_df = pd.read_csv(os.path.join('metrics', f'{name}_examples.csv'))

# %%
plt.figure(figsize=(20, 5))
hist_ss.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
metrics_df['mean'].plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
metrics_df['std'].plot.line()
# Out:
# <AxesSubplot:>

# %%
bins = pd.qcut(example_df['purchases_30d__count'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                    y     uplift
# w   purchases_30d__count
# 0.0 (0.999, 2.0]          202.829050  -0.618178
#     (2.0, 3.0]            256.898960 -14.422262
#     (3.0, 4.0]            257.694675 -17.987628
#     (4.0, 10.0]           258.426936 -19.590756
# 1.0 (0.999, 2.0]          206.625274  -0.599588
#     (2.0, 3.0]            244.126343 -14.278259
#     (3.0, 4.0]            237.370450 -17.927478
#     (4.0, 10.0]           237.842184 -19.480245

# %%
bins = pd.qcut(example_df['purchases_sum_30d__sum'], q=10, duplicates='drop')
example_df.groupby(['w', bins]).agg({'y': 'mean',
                                     'uplift': 'mean'})
# Out:
#                                             y     uplift
# w   purchases_sum_30d__sum
# 0.0 (85.02799999999999, 1027.773]  113.381924   5.555259
#     (1027.773, 1486.169]           142.074634   1.997729
#     (1486.169, 1908.069]           172.041740  -1.315572
#     (1908.069, 2328.167]           193.264216  -4.477277
#     (2328.167, 2760.356]           213.981228  -7.016517
#     (2760.356, 3244.932]           229.691224 -10.026472
#     (3244.932, 3843.417]           255.955372 -11.520024
#     (3843.417, 4613.921]           294.961684 -13.469759
#     (4613.921, 5664.935]           327.691156 -17.158258
#     (5664.935, 10710.174]          300.287233 -10.403110
# 1.0 (85.02799999999999, 1027.773]  117.004555   5.647720
#     (1027.773, 1486.169]           144.466157   2.136117
#     (1486.169, 1908.069]           171.611987  -1.364090
#     (1908.069, 2328.167]           191.135324  -4.799637
#     (2328.167, 2760.356]           210.865792  -6.940471
#     (2760.356, 3244.932]           226.932555  -9.943338
#     (3244.932, 3843.417]           246.437779 -11.397267
#     (3843.417, 4613.921]           283.993177 -13.317208
#     (4613.921, 5664.935]           315.891878 -17.087883
#     (5664.935, 10710.174]          294.078754 -10.153087
